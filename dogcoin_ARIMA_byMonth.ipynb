# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
from datetime import datetime
import matplotlib.pylab as plt
import calendar
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import warnings
from itertools import product
from datetime import datetime

# %%
df1 = pd.read_csv("dogecoin_data_uptodate.csv")
df = df1.reset_index(drop = True)

# %%
dict1 = {}
for i in range(len(df)):
    year = df['Date'].iloc[i].split(",")[1].split(" ")[1]
    month = list(calendar.month_abbr).index(df['Date'].iloc[i].split(",")[0].split(" ")[0])
    day = df['Date'].iloc[i].split(",")[0].split(" ")[1]
    dict1[datetime(int(year),int(month),int(day))] = df['Open*'].iloc[i]
ts = pd.DataFrame(data=dict1.values(), index=dict1.keys(), columns=["Open"])
ts = ts.sort_index()

# %%
train_size = int(len(ts) * 0.7)
test_size = len(ts) - train_size
test = ts.iloc[train_size:]
ts = ts.iloc[:train_size]

# %%
ts = ts.resample('D').mean()
ts_month = ts.resample('M').mean()
ts_year = ts.resample('A-DEC').mean()
ts_Q = ts.resample('Q-DEC').mean()

# %%
fig = plt.figure(figsize=[15, 7])
plt.suptitle('DogCoin exchanges, mean USD', fontsize=22)

plt.subplot(221)
plt.plot(ts['Open'], '-', label='By Days')
plt.legend()

plt.subplot(222)
plt.plot(ts_month['Open'], '-', label='By Months')
plt.legend()

plt.subplot(223)
plt.plot(ts_year['Open'], '-', label='By Quarters')
plt.legend()

plt.subplot(224)
plt.plot(ts_Q['Open'], '-', label='By Years')
plt.legend()

# plt.tight_layout()
plt.show()
# Out:
# /Users/yuchenxing/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=[15,7])
sm.tsa.seasonal_decompose(ts_month['Open']).plot()
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(ts_month['Open'])[1])
plt.show()
# Out:
# Dickey–Fuller test: p=0.905955

# %%
# Box-Cox Transformations
ts_month['Open_box'], lmbda = stats.boxcox(ts_month['Open'])
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(ts_month['Open'])[1])
# Out:
# Dickey–Fuller test: p=0.905955

# %%
# Seasonal differentiation
ts_month['Open_box_diff'] = ts_month['Open_box'] - ts_month['Open_box'].shift(12)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(ts_month['Open_box_diff'][12:])[1])
# Out:
# Dickey–Fuller test: p=0.453747

# %%
# Regular differentiation
ts_month['Open_box_diff2'] = ts_month.Open_box_diff - ts_month.Open_box_diff.shift(1)
plt.figure(figsize=(15,7))

# STL-decomposition
sm.tsa.seasonal_decompose(ts_month.Open_box_diff2[13:]).plot()   
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(ts_month.Open_box_diff2[13:])[1])

plt.show()
# Out:
# Dickey–Fuller test: p=0.000010

# %%
# Initial approximation of parameters
Qs = range(0, 2)
qs = range(0, 3)
Ps = range(0, 3)
ps = range(0, 3)
D=1
d=1
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)

# Model Selection
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')
for param in parameters_list:
    try:
        model=sm.tsa.statespace.SARIMAX(ts_month.Open_box, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])

# %%
# Best Models
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
#       parameters         aic
# 8   (0, 1, 1, 0)  426.666530
# 7   (0, 1, 0, 1)  427.401024
# 38  (2, 0, 1, 0)  428.091818
# 14  (0, 2, 1, 0)  428.441480
# 10  (0, 1, 2, 0)  428.511162
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                           Open_box   No. Observations:                   51
# Model:             SARIMAX(0, 1, 1)x(1, 1, 0, 12)   Log Likelihood                -210.333
# Date:                            Fri, 13 Dec 2019   AIC                            426.667
# Time:                                    19:50:57   BIC                            431.579
# Sample:                                12-31-2013   HQIC                           428.414
#                                      - 02-28-2018
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.4530      0.158      2.871      0.004       0.144       0.762
# ar.S.L12      -0.5252      0.121     -4.329      0.000      -0.763      -0.287
# sigma2      3380.7390    716.044      4.721      0.000    1977.318    4784.160
# ===================================================================================
# Ljung-Box (Q):                         nan   Jarque-Bera (JB):                 7.39
# Prob(Q):                               nan   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.52   Skew:                            -0.73
# Prob(H) (two-sided):                  0.25   Kurtosis:                         4.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))

# %%
# Prediction
ts_month2 = ts_month[['Open']]
date_list = test.index
future = pd.DataFrame(index=date_list, columns=['Open'])
ts_month2 = pd.concat([ts_month2, future])
ts_month2['forecast'] = invboxcox(best_model.predict(start=0, end=100), lmbda)
ts_month2 = ts_month2[1:100]
plt.figure(figsize=(15,7))
ts_month2.Open.plot()
ts_month2.forecast.plot(color='r', ls='--', label='Predicted Open')
plt.legend()
plt.title('DogCoin exchanges, by months')
plt.ylabel('mean USD')
plt.show()
